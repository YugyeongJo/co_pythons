# %% [markdown]
# <a href="https://colab.research.google.com/github/YugyeongJo/co_pythons/blob/main/docs/quests/DDA/multivariate_OrdersDeliveryList.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df_SMDWD = pd.read_csv('/content/ShoppingMallDeliveryWithDate(1).csv')
df_SMDWD[:4]
# Out:
#     결제수단                   배송번호               배송시작일               배송완료일  \
# 0  무통장입금  D-20181227-0000648-00  2019-01-07 오전 8:56  2019-01-11 오전 5:32
# 1  무통장입금  D-20181229-0000119-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 2  무통장입금  D-20181230-0000100-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 3  무통장입금  D-20181231-0000087-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
#
#    상품구매금액    상품번호  수량   주문경로       주문일
# 0   71450  1077.0   1  PC쇼핑몰  20181227
# 1  141240    42.0   2   모바일웹  20181229
# 2   13910  1271.0   1   모바일웹  20181230
# 3   81600  1085.0   1   모바일웹  20181231

# %%
df_SMDWD.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46749 entries, 0 to 46748
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   결제수단    46749 non-null  object
#  1   배송번호    46749 non-null  object
#  2   배송시작일   46749 non-null  object
#  3   배송완료일   46749 non-null  object
#  4   상품구매금액  46749 non-null  int64
#  5   상품번호    46661 non-null  float64
#  6   수량      46749 non-null  int64
#  7   주문경로    46749 non-null  object
#  8   주문일     46749 non-null  int64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 3.2+ MB

# %%
df_SMDWD.columns
# Out:
# Index(['결제수단', '배송번호', '배송시작일', '배송완료일', '상품구매금액', '상품번호', '수량', '주문경로',
#        '주문일'],
#       dtype='object')

# %% [markdown]
# ## 1. 상품구매금액이 80,000원 이상인 주문들을 찾으세요.

# %%
df_SMDWD.query('상품구매금액 >= 80000')
# Out:
#             결제수단                   배송번호                배송시작일  \
# 1          무통장입금  D-20181229-0000119-00   2019-01-03 오전 9:30
# 3          무통장입금  D-20181231-0000087-00   2019-01-03 오전 9:30
# 4          무통장입금  D-20181231-0000108-00   2019-01-07 오전 8:56
# 6          무통장입금  D-20181231-0000184-00   2019-01-03 오전 9:30
# 8          무통장입금  D-20181231-0000184-02   2019-01-03 오전 9:30
# ...          ...                    ...                  ...
# 46735  적립금,무통장입금  D-20171228-0000104-01   2017-12-29 오후 4:32
# 46736         카드  D-20171228-0000126-00   2017-12-29 오후 4:32
# 46742      무통장입금  D-20171229-0000026-00   2017-12-29 오후 4:32
# 46745         카드  D-20171229-0000043-00   2018-01-03 오전 9:45
# 46748         카드  D-20171231-0000026-00  2018-01-03 오후 12:43
#
#                     배송완료일  상품구매금액    상품번호  수량   주문경로       주문일
# 1      2019-01-07 오전 5:32  141240    42.0   2   모바일웹  20181229
# 3      2019-01-07 오전 5:32   81600  1085.0   1   모바일웹  20181231
# ...

# %% [markdown]
# ## 2. 모바일웹을 통해 주문된 상품 중, 상품구매금액이 평균 이상인 주문들을 찾으세요.

# %%
condition_orderway = '주문경로 == "모바일웹"'
df_SMDWD_orderway = df_SMDWD.query(condition_orderway)

average = int(df_SMDWD_orderway['상품구매금액'].mean()) #모바일웹 주문경로인 data들의 상품구매금액 평균값 구하기

condition_average = f'상품구매금액 >= {average}'  #구한 평균값을 f-string 이용해서 넣어주기
df_SMDWD_orderway.query(condition_average)
# Out:
#             결제수단                   배송번호                배송시작일  \
# 1          무통장입금  D-20181229-0000119-00   2019-01-03 오전 9:30
# 3          무통장입금  D-20181231-0000087-00   2019-01-03 오전 9:30
# 4          무통장입금  D-20181231-0000108-00   2019-01-07 오전 8:56
# 5          무통장입금  D-20181231-0000108-01   2019-01-07 오전 8:56
# 21     적립금,무통장입금  D-20181231-0000512-00   2019-01-03 오전 9:30
# ...          ...                    ...                  ...
# 46730        휴대폰  D-20171228-0000092-00   2017-12-28 오후 6:20
# 46736         카드  D-20171228-0000126-00   2017-12-29 오후 4:32
# 46742      무통장입금  D-20171229-0000026-00   2017-12-29 오후 4:32
# 46745         카드  D-20171229-0000043-00   2018-01-03 오전 9:45
# 46748         카드  D-20171231-0000026-00  2018-01-03 오후 12:43
#
#                     배송완료일  상품구매금액    상품번호  수량  주문경로       주문일
# 1      2019-01-07 오전 5:32  141240    42.0   2  모바일웹  20181229
# 3      2019-01-07 오전 5:32   81600  1085.0   1  모바일웹  20181231
# ...

# %% [markdown]
# ## 3. 2019년 1월 7일 이전에 배송이 시작된 주문들을 찾으세요.

# %%
df_SMDWD
# Out:
#         결제수단                   배송번호                배송시작일               배송완료일  \
# 0      무통장입금  D-20181227-0000648-00   2019-01-07 오전 8:56  2019-01-11 오전 5:32
# 1      무통장입금  D-20181229-0000119-00   2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 2      무통장입금  D-20181230-0000100-00   2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 3      무통장입금  D-20181231-0000087-00   2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 4      무통장입금  D-20181231-0000108-00   2019-01-07 오전 8:56  2019-01-11 오전 5:32
# ...      ...                    ...                  ...                 ...
# 46744     카드  D-20171229-0000036-00   2017-12-29 오후 4:32  2018-01-02 오전 5:31
# 46745     카드  D-20171229-0000043-00   2018-01-03 오전 9:45  2018-01-07 오전 5:38
# 46746     카드  D-20171230-0000022-01   2018-01-02 오후 7:06  2018-01-11 오전 2:46
# 46747     카드  D-20171231-0000017-01   2018-01-03 오후 2:00  2018-01-06 오후 6:06
# 46748     카드  D-20171231-0000026-00  2018-01-03 오후 12:43  2018-01-07 오전 5:38
#
#        상품구매금액    상품번호  수량    주문경로       주문일
# ...

# %%
start = df_SMDWD.query('배송시작일 <= "2019-01-07"')

# %%
# df_SMDWD['배송시작일'] = df_SMDWD['배송시작일'].str.slice(start=0, stop=10)
# df_SMDWD['배송시작일'] = pd.to_datetime(df_SMDWD['배송시작일'])

# %%
# year = df_SMDWD['배송시작일'].dt.year
# month = df_SMDWD['배송시작일'].dt.month
# day = df_SMDWD['배송시작일'].dt.day

# %%
# df_SMDWD['배송시작일'] = f'{year}{month}{day}'
# df_SMDWD['배송시작일']

# %%
# condition_delivery_start = '배송시작일 < 20190107'
# df_SMDWD.query(condition_delivery_start)

# %% [markdown]
# ## 4. 배송 시작일과 배송 완료일이 3일 이상 차이 나는 주문들을 찾으세요

# %%
def convert_time(x):
    date, ampm, time = x.split()
    if ampm == "오후" and time != "12:00":
        hour, minute = map(int, time.split(":"))
        time = f"{hour+12 if hour != 12 else hour}:{minute}"
    return pd.to_datetime(f"{date} {time}", format="%Y-%m-%d %H:%M")

df_SMDWD["배송시작일_datetime"]=df_SMDWD["배송시작일"].apply(convert_time)
df_SMDWD["배송완료일_datetime"]=df_SMDWD["배송완료일"].apply(convert_time)

df_SMDWD["배송소요일"] = df_SMDWD["배송완료일_datetime"]-df_SMDWD["배송시작일_datetime"]
df_SMDWD["배송소요일"] = df_SMDWD["배송소요일"].dt.days
df_SMDWD["배송소요일"]

# %%
df_SMDWD.query('배송소요일 >= 3')
# Out:
#         결제수단                   배송번호                배송시작일               배송완료일  \
# 0      무통장입금  D-20181227-0000648-00   2019-01-07 오전 8:56  2019-01-11 오전 5:32
# 1      무통장입금  D-20181229-0000119-00   2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 2      무통장입금  D-20181230-0000100-00   2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 3      무통장입금  D-20181231-0000087-00   2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 4      무통장입금  D-20181231-0000108-00   2019-01-07 오전 8:56  2019-01-11 오전 5:32
# ...      ...                    ...                  ...                 ...
# 46744     카드  D-20171229-0000036-00   2017-12-29 오후 4:32  2018-01-02 오전 5:31
# 46745     카드  D-20171229-0000043-00   2018-01-03 오전 9:45  2018-01-07 오전 5:38
# 46746     카드  D-20171230-0000022-01   2018-01-02 오후 7:06  2018-01-11 오전 2:46
# 46747     카드  D-20171231-0000017-01   2018-01-03 오후 2:00  2018-01-06 오후 6:06
# 46748     카드  D-20171231-0000026-00  2018-01-03 오후 12:43  2018-01-07 오전 5:38
#
# ...

# %% [markdown]
# ## 5. 무통장입금을 결제수단으로 사용한 주문 중, 상품번호가 1000번 이상인 주문들을 찾으세요.

# %%
condition_payment = '결제수단 == "무통장입금"'
condition_item = '상품번호 >= 1000'
conditions = f'{condition_payment} and {condition_item}'
df_SMDWD.query(conditions)
# Out:
#         결제수단                   배송번호                배송시작일               배송완료일  \
# 0      무통장입금  D-20181227-0000648-00   2019-01-07 오전 8:56  2019-01-11 오전 5:32
# 2      무통장입금  D-20181230-0000100-00   2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 3      무통장입금  D-20181231-0000087-00   2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 4      무통장입금  D-20181231-0000108-00   2019-01-07 오전 8:56  2019-01-11 오전 5:32
# 5      무통장입금  D-20181231-0000108-01   2019-01-07 오전 8:56  2019-01-11 오전 5:32
# ...      ...                    ...                  ...                 ...
# 45110  무통장입금  D-20181231-0000985-01   2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 45111  무통장입금  D-20181231-0000985-02   2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 45112  무통장입금  D-20181231-0000985-03   2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 45117  무통장입금  D-20181231-0000985-04   2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 45118  무통장입금  D-20181226-0000807-01  2019-01-11 오전 10:10  2019-01-15 오전 5:32
#
# ...

# %% [markdown]
# ## 6. 상품번호가 50번 이하이거나 1000번 이상인 주문들을 찾으세요.

# %%
condition_under_50 = '상품번호 <= 50'
condition_upper_1000 = '상품번호 >= 1000'
conditions = f'{condition_under_50} or {condition_upper_1000}'
df_SMDWD.query(conditions)
# Out:
#          결제수단                   배송번호               배송시작일               배송완료일  \
# 0       무통장입금  D-20181227-0000648-00  2019-01-07 오전 8:56  2019-01-11 오전 5:32
# 1       무통장입금  D-20181229-0000119-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 2       무통장입금  D-20181230-0000100-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 3       무통장입금  D-20181231-0000087-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 4       무통장입금  D-20181231-0000108-00  2019-01-07 오전 8:56  2019-01-11 오전 5:32
# ...       ...                    ...                 ...                 ...
# 46697  적립금,카드  D-20171226-0000098-00  2017-12-26 오후 5:39  2017-12-30 오전 5:36
# 46698  적립금,카드  D-20171226-0000098-01  2017-12-26 오후 5:39  2017-12-30 오전 5:36
# 46720   무통장입금  D-20171228-0000011-00  2017-12-28 오후 6:20  2018-01-01 오전 5:37
# 46722   무통장입금  D-20171228-0000041-01  2017-12-28 오후 6:20  2018-01-01 오전 5:37
# 46733     휴대폰  D-20171228-0000092-03  2017-12-28 오후 6:20  2018-01-01 오전 5:37
#
# ...

# %% [markdown]
# ## 7. 주문일이 20181231인 주문 중, 수량이 1개 이상인 주문들을 찾으세요.

# %%
condition_orderdate_20181231 = '주문일 == 20181231'
condition_item_amount = '수량 >= 1'
conditions_07 = f'{condition_orderdate_20181231} and {condition_item_amount}'
df_SMDWD.query(conditions_07)
# Out:
#         결제수단                   배송번호               배송시작일               배송완료일  \
# 3      무통장입금  D-20181231-0000087-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 4      무통장입금  D-20181231-0000108-00  2019-01-07 오전 8:56  2019-01-11 오전 5:32
# 5      무통장입금  D-20181231-0000108-01  2019-01-07 오전 8:56  2019-01-11 오전 5:32
# 6      무통장입금  D-20181231-0000184-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 7      무통장입금  D-20181231-0000184-01  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# ...      ...                    ...                 ...                 ...
# 45113  무통장입금  D-20181231-0000985-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 45114     카드  D-20181231-0001006-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 45115     카드  D-20181231-0001006-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 45116     카드  D-20181231-0000595-04  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 45117  무통장입금  D-20181231-0000985-04  2019-01-03 오전 9:30  2019-01-07 오전 5:32
#
# ...

# %% [markdown]
# ## 8. PC쇼핑몰을 통해 주문된 상품 중, 배송번호가 'D-20181231'로 시작하는 주문들을 찾으세요.

# %%
df_SMDWD['주문경로'].value_counts()
# Out:
# PC쇼핑몰     25695
# 모바일웹      18531
# 네이버 페이     2523
# Name: 주문경로, dtype: int64

# %%
condition_orderway_PC = df_SMDWD['주문경로'] == 'PC쇼핑몰'
# condition_orderway_PC

df_SMDWD_delivery_contain = df_SMDWD['배송번호'].str.contains('D-20181231')
# df_SMDWD_delivery_contain

conditions_08 = condition_orderway_PC & df_SMDWD_delivery_contain
df_SMDWD.loc[conditions_08]
# Out:
#         결제수단                   배송번호               배송시작일               배송완료일  \
# 6      무통장입금  D-20181231-0000184-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 7      무통장입금  D-20181231-0000184-01  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 8      무통장입금  D-20181231-0000184-02  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 9      무통장입금  D-20181231-0000184-03  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 10     무통장입금  D-20181231-0000205-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# ...      ...                    ...                 ...                 ...
# 45097     카드  D-20181231-0000822-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 45102     카드  D-20181231-0000927-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 45103     카드  D-20181231-0000927-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 45104     카드  D-20181231-0000953-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
# 45105     카드  D-20181231-0000953-00  2019-01-03 오전 9:30  2019-01-07 오전 5:32
#
# ...

# %% [markdown]
# ## 9. 상품구매금액이 70,000원 이상 100,000원 이하인 주문들 중, 수량이 1개인 주문들을 찾으세요.

# %%
condition_purchase_amount = '70000 <= 상품구매금액 <= 100000'
condition_item_amount = '수량 >= 1'
conditions_09 = f'{condition_purchase_amount} and {condition_item_amount}'
df_SMDWD.query(conditions_09)
# Out:
#         결제수단                   배송번호                배송시작일                배송완료일  \
# 0      무통장입금  D-20181227-0000648-00   2019-01-07 오전 8:56   2019-01-11 오전 5:32
# 3      무통장입금  D-20181231-0000087-00   2019-01-03 오전 9:30   2019-01-07 오전 5:32
# 4      무통장입금  D-20181231-0000108-00   2019-01-07 오전 8:56   2019-01-11 오전 5:32
# 5      무통장입금  D-20181231-0000108-01   2019-01-07 오전 8:56   2019-01-11 오전 5:32
# 6      무통장입금  D-20181231-0000184-00   2019-01-03 오전 9:30   2019-01-07 오전 5:32
# ...      ...                    ...                  ...                  ...
# 46737     카드  D-20171228-0000132-01   2017-12-29 오후 4:34   2018-01-07 오전 4:55
# 46738     카드  D-20171228-0000132-02   2017-12-29 오후 4:34  2018-01-03 오전 10:38
# 46742  무통장입금  D-20171229-0000026-00   2017-12-29 오후 4:32   2018-01-02 오전 5:31
# 46747     카드  D-20171231-0000017-01   2018-01-03 오후 2:00   2018-01-06 오후 6:06
# 46748     카드  D-20171231-0000026-00  2018-01-03 오후 12:43   2018-01-07 오전 5:38
#
# ...

# %% [markdown]
# ## 10. 모바일웹을 통한 주문 중, 배송번호가 'D-20181230' 이후로 시작되고 상품구매금액이 50,000원 이상인 주문들을 찾으세요.

# %%
condition_orderway_mobile = '주문경로 == "모바일웹"'
df_SMDWD_delivery_date = '주문일 >= 20181230'
condition_purchase_amount = '상품구매금액 >= 50000'
conditions_10 = f'{condition_orderway_mobile} and {df_SMDWD_delivery_date} and {condition_purchase_amount}'
df_SMDWD.query(conditions_10)
# Out:
#             결제수단                   배송번호               배송시작일  \
# 3          무통장입금  D-20181231-0000087-00  2019-01-03 오전 9:30
# 4          무통장입금  D-20181231-0000108-00  2019-01-07 오전 8:56
# 5          무통장입금  D-20181231-0000108-01  2019-01-07 오전 8:56
# 21     적립금,무통장입금  D-20181231-0000512-00  2019-01-03 오전 9:30
# 25         무통장입금  D-20181231-0000727-00  2019-01-03 오후 6:19
# ...          ...                    ...                 ...
# 45111      무통장입금  D-20181231-0000985-02  2019-01-03 오전 9:30
# 45112      무통장입금  D-20181231-0000985-03  2019-01-03 오전 9:30
# 45114         카드  D-20181231-0001006-00  2019-01-03 오전 9:30
# 45116         카드  D-20181231-0000595-04  2019-01-03 오전 9:30
# 45117      무통장입금  D-20181231-0000985-04  2019-01-03 오전 9:30
#
#                     배송완료일  상품구매금액    상품번호  수량  주문경로       주문일  \
# 3      2019-01-07 오전 5:32   81600  1085.0   1  모바일웹  20181231
# 4      2019-01-11 오전 5:32   94710  1106.0   1  모바일웹  20181231
# ...
